# %% [markdown]
# E

# %% [markdown]
# # Importing the libraries

# %%
# reading in data
import re
import string
import numpy as np 
import random
import pandas as pd 



#Vissualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go # pip install plotly==4.8.1
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator #pip install wordcloud

#Preprocessing
import nltk
from nltk.corpus import stopwords
from tqdm import tqdm
import os
import nltk
nltk.download('averaged_perceptron_tagger')
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

#modeling
from sklearn.feature_extraction.text import CountVectorizer

#csv paths
import warnings
warnings.filterwarnings("ignore")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# Below is a helper Function which generates random colors which will be used to give different colors to our plots.

# %%
def random_colours(number_of_colors):
    '''
    Simple function for random colours generation.
    Input:
        number_of_colors - integer value indicating the number of colours which are going to be generated.
    Output:
        Color in the following format: ['#E86DA4'] .
    '''
    colors = []
    for i in range(number_of_colors):
        colors.append("#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]))
    return colors

# %% [markdown]
# # Getting Data

# %%
# Load dataset
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
ss_df = pd.read_csv('sample_submission.csv')

# %%
train_df.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954

# %%
print('___basic info of the train data___')
print(train_df.info())
print('Dataset size:', train_df.shape)
print('Columns are:',train_df.columns)

print('___Print the head/Tain of the train data_____')
print(train_df.head())
print('________________________')
print(train_df.tail())
# Out:
# ___basic info of the train data___
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15819 entries, 0 to 15818
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  15819 non-null  int64
#  1   message    15819 non-null  object
#  2   tweetid    15819 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 370.9+ KB
# None
# Dataset size: (15819, 3)
# Columns are: Index(['sentiment', 'message', 'tweetid'], dtype='object')
# ___Print the head/Tain of the train data_____
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
# ________________________
#        sentiment  \
# 15814          1
# 15815          2
# 15816          0
# 15817         -1
# 15818          0
#
#                                                                                                    message  \
# 15814  RT @ezlusztig: They took down the material on global warming, LGBT rights, and health care. But ...
# 15815  RT @washingtonpost: How climate change could be breaking up a 200-million-year-old relationship ...
# 15816  notiven: RT: nytimesworld :What does Trump actually believe about climate change? Rick Perry joi...
# 15817  RT @sara8smiles: Hey liberals the climate change crap is a hoax that ties to #Agenda2030.\nThe C...
# 15818  RT @Chet_Cannon: .@kurteichenwald's 'climate change equation' in 4 screenshots https://t.co/lp7U...
#
#        tweetid
# 15814    22001
# 15815    17856
# 15816   384248
# 15817   819732
# 15818   806319

# %% [markdown]
# As seen above, when we print some basic information about the data. We can notice right away how each row is represented either by int64 or Object (for TextData). Finally after plotting the histogram of the sentiment data, its clear that there more positive examples then negative examples. (1 being denoted as positive sentiment while 0 being denoted as negative.). There are four sentiments in total.

# %% [markdown]
# # Data cleaning and Preprocessing

# %% [markdown]
# ## Removing the noise

# %% [markdown]
# Replacing contaction phrases

# %%
contractions_dict = contractions = { 
"ain't": "am not / are not / is not / has not / have not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is / how does",
"I'd": "I had / I would",
"I'd've": "I would have",
"I'll": "I shall / I will",
"I'll've": "I shall have / I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}


def expand_contractions(text):
    for word in text.split():
        if word.lower() in contractions_dict:
            text = text.replace(word,contractions_dict[word.lower()])
    return text

train_df['fixed_cntractions'] = train_df['message'].apply(lambda x: expand_contractions(x))
test_df['fixed_cntractions'] = test_df['message'].apply(lambda x: expand_contractions(x))

# %% [markdown]
# ### Dealig with the punctuations and the links present in the messages

# %%
def remov_pnct(text):
    '''The Function makes text lowercase,removes links, punctuation(!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~)
    and words containing numbers.'''
    
    text = str(text).lower() #Make text lowercase
    text = ' '.join(re.sub("(@[A-Za-z0-9]+)|(#[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())# remove @user, #word and link
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text) ##remove punctuation
    text = re.sub('\n', '', text)
    text = ''.join([i for i in text[:] if not i.isdigit()]) #remove numbers
    return text

train_df['clean_message'] = train_df['fixed_cntractions'].apply(lambda x: remov_pnct(x))
test_df['clean_message'] = test_df['fixed_cntractions'].apply(lambda x: remov_pnct(x))

# %%
train_df.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid  \
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
#
#                                                                                      fixed_cntractions  \
# 0  PolySciMajor EPA chief does not think carbon dioxide is main cause of global warming and.. wait,...
# 1                             it has / it is not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, sexist, climate change denying bigot is ...
#
#                                                                                          clean_message
# 0  polyscimajor epa chief does not think carbon dioxide is main cause of global warming and wait wh...
# 1                               it has it is not like we lack evidence of anthropogenic global warming
# 2                 rt researchers say we have three years to act on climate change before it s too late
# 3                                               wired  was a pivotal year in the war on climate change
# 4            rt it has it is  and a racist sexist climate change denying bigot is leading in the polls

# %% [markdown]
# ### Parts of Speech Tagging (POS)

# %%
train_df['message_POS'] = train_df['clean_message'].apply(lambda x: nltk.pos_tag(nltk.word_tokenize(x)))
test_df['message_POS'] = test_df['clean_message'].apply(lambda x: nltk.pos_tag(nltk.word_tokenize(x)))
train_df.head()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\elton\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid  \
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
#
#                                                                                      fixed_cntractions  \
# 0  PolySciMajor EPA chief does not think carbon dioxide is main cause of global warming and.. wait,...
# 1                             it has / it is not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, sexist, climate change denying bigot is ...
#
#                                                                                          clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is main cause of global warming and wait wh...
# 1                               it has it is not like we lack evidence of anthropogenic global warming
# 2                 rt researchers say we have three years to act on climate change before it s too late
# 3                                               wired  was a pivotal year in the war on climate change
# 4            rt it has it is  and a racist sexist climate change denying bigot is leading in the polls
#
#                                                                                            message_POS
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ), (not, RB), (think, VB), (carbon, NN), ...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB), (like, IN), (we, PRP), (lack, VBP), (ev...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (have, VBP), (three, CD), (years, NNS), (t...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year, NN), (in, IN), (the, DT), (war, NN), (...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (and, CC), (a, DT), (racist, NN), (sexis...

# %% [markdown]
# ### Lemmatisation

# %%
def lemmatizer(text):        
    sent = []
    doc = nlp(text)
    for word in doc:
        sent.append(word.lemma_)
    return " ".join(sent)

# %%
train_df["lemmaa"] =train_df.apply(lambda x: lemmatizer(x['clean_message']), axis=1)
test_df["lemmaa"] =test_df.apply(lambda x: lemmatizer(x['clean_message']), axis=1)

# %%
train_df.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid  \
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
#
#                                                                                      fixed_cntractions  \
# 0  PolySciMajor EPA chief does not think carbon dioxide is main cause of global warming and.. wait,...
# 1                             it has / it is not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, sexist, climate change denying bigot is ...
#
#                                                                                          clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is main cause of global warming and wait wh...
# 1                               it has it is not like we lack evidence of anthropogenic global warming
# 2                 rt researchers say we have three years to act on climate change before it s too late
# 3                                               wired  was a pivotal year in the war on climate change
# 4            rt it has it is  and a racist sexist climate change denying bigot is leading in the polls
#
#                                                                                            message_POS  \
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ), (not, RB), (think, VB), (carbon, NN), ...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB), (like, IN), (we, PRP), (lack, VBP), (ev...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (have, VBP), (three, CD), (years, NNS), (t...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year, NN), (in, IN), (the, DT), (war, NN), (...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (and, CC), (a, DT), (racist, NN), (sexis...
#
#                                                                                                 lemmaa
# 0  polyscimajor epa chief do not think carbon dioxide be main cause of global warming and wait what...
# 1                  -PRON- have -PRON- be not like -PRON- lack evidence of anthropogenic global warming
# 2           rt researcher say -PRON- have three year to act on climate change before -PRON- s too late
# 3                                               wired   be a pivotal year in the war on climate change
# 4         rt -PRON- have -PRON- be   and a racist sexist climate change deny bigot be lead in the poll

# %% [markdown]
# Removing the _PRON_ and rt   form column lemmaa

# %%
def remove(text):
    '''stoc'''
    text = text.remove(-PRON-)
    text = text.remove(rt)
    return text

# %%
train_df['clean_lemma'] = train_df['lemmaa'].apply(lambda x: remove(x))
test_df['clean_lemma'] = test_df['lemmaa'].apply(lambda x: remove(x))
train_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-284-fd7ef015a0f4> in <module>
# ----> 1 train_df['clean_lemma'] = train_df['lemmaa'].apply(lambda x: remove(x))
#       2 test_df['clean_lemma'] = test_df['lemmaa'].apply(lambda x: remove(x))
#       3 train_df.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-284-fd7ef015a0f4> in <lambda>(x)
# ----> 1 train_df['clean_lemma'] = train_df['lemmaa'].apply(lambda x: remove(x))
#       2 test_df['clean_lemma'] = test_df['lemmaa'].apply(lambda x: remove(x))
#       3 train_df.head()
#
# <ipython-input-281-a5b2525c51db> in remove(text)
#       1 def remove(text):
#       2     '''stoc'''
# ----> 3     text = text.remove('-PRON-')
#       4     text = text.remove('rt')
#       5     return text
#
# AttributeError: 'str' object has no attribute 'remove'

# %% [markdown]
# ## Tokenizing

# %%
def tokenization(text):
    '''stoc'''
    text = re.split('\W+', text)
    return text

# %%
train_df['tokenized_message'] = train_df['clean_lemma'].apply(lambda x: tokenization(x.lower()))
test_df['tokenized_message'] = test_df['clean_lemma'].apply(lambda x: tokenization(x.lower()))
train_df.head()
# Out:
#    sentiment                                                      message  \
# 0          1  PolySciMajor EPA chief doesn't think carbon dioxide is m...
# 1          1  It's not like we lack evidence of anthropogenic global w...
# 2          2  RT @RawStory: Researchers say we have three years to act...
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year in the wa...
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, cl...
#
#    tweetid                                            fixed_cntractions  \
# 0   625221  PolySciMajor EPA chief does not think carbon dioxide is ...
# 1   126103  it has / it is not like we lack evidence of anthropogeni...
# 2   698562  RT @RawStory: Researchers say we have three years to act...
# 3   573736  #TodayinMaker# WIRED : 2016 was a pivotal year in the wa...
# 4   466954  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, ...
#
#                                                  clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is ...
# 1  it has it is not like we lack evidence of anthropogenic ...
# 2  rt researchers say we have three years to act on climate...
# 3       wired  was a pivotal year in the war on climate change
# 4  rt it has it is  and a racist sexist climate change deny...
#
#                                                    message_POS  \
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ)...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB),...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (h...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), ...
#
#                                                         lemmaa  \
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1  -PRON- have -PRON- be not like -PRON- lack evidence of a...
# 2  rt researcher say -PRON- have three year to act on clima...
# 3       wired   be a pivotal year in the war on climate change
# 4  rt -PRON- have -PRON- be   and a racist sexist climate c...
#
#                                                clean_stp_words  \
# 0  [polyscimajor, epa, chief, not, think, carbon, dioxide, ...
# 1  [, pron, pron, not, like, pron, lack, evidence, anthropo...
# 2  [rt, researcher, say, pron, three, year, act, climate, c...
# 3                 [wired, pivotal, year, war, climate, change]
# 4  [rt, pron, pron, racist, sexist, climate, change, deny, ...
#
#                                              tokenized_message  \
# 0  [polyscimajor, epa, chief, do, not, think, carbon, dioxi...
# 1  [, have, be, not, like, lack, evidence, of, anthropogeni...
# 2  [, researcher, say, have, three, year, to, act, on, clim...
# 3  [wired, be, a, pivotal, year, in, the, war, on, climate,...
# 4  [, have, be, and, a, racist, sexist, climate, change, de...
#
#                                                            cjk  \
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1    have   be not like   lack evidence of anthropogenic gl...
# 2  rt researcher say   have three year to act on climate ch...
# 3       wired   be a pivotal year in the war on climate change
# 4  rt   have   be   and a racist sexist climate change deny...
#
#                                                    clean_lemma
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1   have  be not like  lack evidence of anthropogenic globa...
# 2   researcher say  have three year to act on climate chang...
# 3       wired   be a pivotal year in the war on climate change
# 4    have  be   and a racist sexist climate change deny big...

# %% [markdown]
# ### Stop Words

# %%
#import nltk
#nltk.download('stopwords')
#from nltk.corpus import stopwords
#print(sorted(stopwords.words('english')))

# %%
stop = ['a', 'about', 'above','after', 'again', 'against', 
        'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 
        'as', 'at', 'be', 'because', 'been', 'before', 'being', 
        'below', 'between', 'both', 'but', 'by', 'can', 'couldn', 
        "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', 
        "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 
        'for', 'from', 'further', 'had', 'hadn', 
        "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 
        'he', 'her', 'here', 'hers', 'herself', 'him', 'himself', 'his', 'how', 'i', 
        'if', 'in', 'into', 'is', 'isn', "isn't", 'it', "it's", 'its', 'itself', 'just', 
        'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 
        'my', 'myself', 'needn', "needn't", 'no', 'nor','now', 'o', 'of', 'off', 
        'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 
        're', 's', 'same', 'shan', "shan't", 'she', "she's", 'should', "should've", 'shouldn', 
        "shouldn't", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 
        'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', 'this', 'those', 
        'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 
        'we', 'were', 'weren', "weren't", 'what', 'when', 'where', 'which', 'while', 'who', 
        'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', 
        "you'd", "you'll", "you're", "you've", 'your', 'yours', 'yourself', 'yourselves']

# %%
'of' in stop# is removed from the stop words
# Out:
# True

# %%
train_df['clean_stp_words'] = train_df['tokenized_message'].apply(lambda x: [item for item in x if item not in stop])
test_df['clean_stp_words'] = test_df['tokenized_message'].apply(lambda x: [item for item in x if item not in stop])
train_df.head()
# Out:
#    sentiment                                                      message  \
# 0          1  PolySciMajor EPA chief doesn't think carbon dioxide is m...
# 1          1  It's not like we lack evidence of anthropogenic global w...
# 2          2  RT @RawStory: Researchers say we have three years to act...
# 3          1  #TodayinMaker# WIRED : 2016 was a pivotal year in the wa...
# 4          1  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, cl...
#
#    tweetid                                            fixed_cntractions  \
# 0   625221  PolySciMajor EPA chief does not think carbon dioxide is ...
# 1   126103  it has / it is not like we lack evidence of anthropogeni...
# 2   698562  RT @RawStory: Researchers say we have three years to act...
# 3   573736  #TodayinMaker# WIRED : 2016 was a pivotal year in the wa...
# 4   466954  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, ...
#
#                                                  clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is ...
# 1  it has it is not like we lack evidence of anthropogenic ...
# 2  rt researchers say we have three years to act on climate...
# 3       wired  was a pivotal year in the war on climate change
# 4  rt it has it is  and a racist sexist climate change deny...
#
#                                                    message_POS  \
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ)...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB),...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (h...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), ...
#
#                                                         lemmaa  \
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1  -PRON- have -PRON- be not like -PRON- lack evidence of a...
# 2  rt researcher say -PRON- have three year to act on clima...
# 3       wired   be a pivotal year in the war on climate change
# 4  rt -PRON- have -PRON- be   and a racist sexist climate c...
#
#                                                clean_stp_words  \
# 0  [polyscimajor, epa, chief, not, think, carbon, dioxide, ...
# 1  [, not, like, lack, evidence, anthropogenic, global, war...
# 2  [, researcher, say, three, year, act, climate, change, l...
# 3                 [wired, pivotal, year, war, climate, change]
# 4  [, racist, sexist, climate, change, deny, bigot, lead, p...
#
#                                              tokenized_message  \
# 0  [polyscimajor, epa, chief, do, not, think, carbon, dioxi...
# 1  [, have, be, not, like, lack, evidence, of, anthropogeni...
# 2  [, researcher, say, have, three, year, to, act, on, clim...
# 3  [wired, be, a, pivotal, year, in, the, war, on, climate,...
# 4  [, have, be, and, a, racist, sexist, climate, change, de...
#
#                                                            cjk  \
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1    have   be not like   lack evidence of anthropogenic gl...
# 2  rt researcher say   have three year to act on climate ch...
# 3       wired   be a pivotal year in the war on climate change
# 4  rt   have   be   and a racist sexist climate change deny...
#
#                                                    clean_lemma
# 0  polyscimajor epa chief do not think carbon dioxide be ma...
# 1   have  be not like  lack evidence of anthropogenic globa...
# 2   researcher say  have three year to act on climate chang...
# 3       wired   be a pivotal year in the war on climate change
# 4    have  be   and a racist sexist climate change deny big...

# %%
train_df['clean_stp_words'][1]
# Out:
# ['', 'not', 'like', 'lack', 'evidence', 'anthropogenic', 'global', 'warming']

# %% [markdown]
# # Creating features

# %% [markdown]
# Getting the number of clean words and comparing them with that  raw from the message and clean message columns.

# %%
#train data frame
train_df['Num_words_raw'] = train_df['message'].apply(lambda x:len(str(x).split())) 
train_df['Num_words_clean'] = train_df['clean_stp_words'].apply(lambda x:len(str(x).split()))
#Difference in Number of words text and Selected Text
train_df['difference_in_wordsNo'] = abs(train_df['Num_words_raw'] - train_df['Num_words_clean']) 
#test data frame
test_df['Num_words_raw'] = test_df['message'].apply(lambda x:len(str(x).split())) 
test_df['Num_words_clean'] = test_df['clean_stp_words'].apply(lambda x:len(str(x).split())) 
#Difference in Number of words text and Selected Text
test_df['difference_in_wordsNo'] = abs(test_df['Num_words_raw'] - test_df['Num_words_clean'])

# %%
train_df.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid  \
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
#
#                                                                                      fixed_cntractions  \
# 0  PolySciMajor EPA chief does not think carbon dioxide is main cause of global warming and.. wait,...
# 1                             it has / it is not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, sexist, climate change denying bigot is ...
#
#                                                                                          clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is main cause of global warming and wait wh...
# 1                               it has it is not like we lack evidence of anthropogenic global warming
# 2                 rt researchers say we have three years to act on climate change before it s too late
# 3                                               wired  was a pivotal year in the war on climate change
# 4            rt it has it is  and a racist sexist climate change denying bigot is leading in the polls
#
#                                                                                      tokenized_message  \
# 0  [polyscimajor, epa, chief, do, not, think, carbon, dioxide, be, main, cause, of, global, warming...
# 1        [, pron, have, pron, be, not, like, pron, lack, evidence, of, anthropogenic, global, warming]
# 2  [rt, researcher, say, pron, have, three, year, to, act, on, climate, change, before, pron, s, to...
# 3                                     [wired, be, a, pivotal, year, in, the, war, on, climate, change]
# 4  [rt, pron, have, pron, be, and, a, racist, sexist, climate, change, deny, bigot, be, lead, in, t...
#
#                                                                                            message_POS  \
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ), (not, RB), (think, VB), (carbon, NN), ...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB), (like, IN), (we, PRP), (lack, VBP), (ev...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (have, VBP), (three, CD), (years, NNS), (t...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year, NN), (in, IN), (the, DT), (war, NN), (...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (and, CC), (a, DT), (racist, NN), (sexis...
#
#                                                                                                 lemmaa  \
# 0  polyscimajor epa chief do not think carbon dioxide be main cause of global warming and wait what...
# 1                  -PRON- have -PRON- be not like -PRON- lack evidence of anthropogenic global warming
# 2           rt researcher say -PRON- have three year to act on climate change before -PRON- s too late
# 3                                               wired   be a pivotal year in the war on climate change
# 4         rt -PRON- have -PRON- be   and a racist sexist climate change deny bigot be lead in the poll
#
#                                                                                     clean_stp_words  \
# 0  [polyscimajor, epa, chief, not, think, carbon, dioxide, main, cause, global, warming, wait, via]
# 1                   [, pron, pron, not, like, pron, lack, evidence, anthropogenic, global, warming]
# 2                        [rt, researcher, say, pron, three, year, act, climate, change, pron, late]
# 3                                                      [wired, pivotal, year, war, climate, change]
# 4                        [rt, pron, pron, racist, sexist, climate, change, deny, bigot, lead, poll]
#
#    Num_words_raw  Num_words_clean  difference_in_wordsNo
# 0             19               13                      6
# 1             10               11                      1
# 2             19               11                      8
# 3             15                6                      9
# 4             18               11                      7

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Taking a closer look at the distribution of tweeter messages in the train set.

# %%
temp = train_df.groupby('sentiment').count()['message'].reset_index().sort_values(by='message',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style  type="text/css" >
#     #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row0_col0 {
#             background-color:  #796eb2;
#             color:  #000000;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row1_col0 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row1_col1 {
#             background-color:  #c9c9e2;
#             color:  #000000;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row2_col0 {
#             background-color:  #c6c7e1;
#             color:  #000000;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row2_col1 {
#             background-color:  #eceaf3;
#             color:  #000000;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row3_col0 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row3_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }</style><table id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sentiment</th>        <th class="col_heading level0 col1" >message</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >2</th>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row0_col1" class="data row0 col1" >8530</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row1_col1" class="data row1 col1" >3640</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >1</th>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row2_col1" class="data row2 col1" >2353</td>
#             </tr>
#             <tr>
#                         <th id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >0</th>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row3_col0" class="data row3 col0" >-1</td>
#                         <td id="T_6d2b1324_af51_11ea_b1f4_fbdfd0c9d569row3_col1" class="data row3 col1" >1296</td>
#             </tr>
#     </tbody></table>

# %%
fig = px.funnel(temp, x='sentiment', y='message', color='sentiment')
fig.show()
# Out:
# <div>
#
#
#             <div id="1f922fe9-77b8-4d8a-bfa5-c7654e012167" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f922fe9-77b8-4d8a-bfa5-c7654e012167")) {
#                     Plotly.newPlot(
#                         '1f922fe9-77b8-4d8a-bfa5-c7654e012167',
#                         [{"hovertemplate": "sentiment=%{x}<br>message=%{y}<extra></extra>", "legendgroup": "1", "marker": {"color": "#636efa"}, "name": "1", "orientation": "v", "showlegend": true, "type": "funnel", "x": [1], "xaxis": "x", "y": [8530], "yaxis": "y"}, {"hovertemplate": "sentiment=%{x}<br>message=%{y}<extra></extra>", "legendgroup": "2", "marker": {"color": "#EF553B"}, "name": "2", "orientation": "v", "showlegend": true, "type": "funnel", "x": [2], "xaxis": "x", "y": [3640], "yaxis": "y"}, {"hovertemplate": "sentiment=%{x}<br>message=%{y}<extra></extra>", "legendgroup": "0", "marker": {"color": "#00cc96"}, "name": "0", "orientation": "v", "showlegend": true, "type": "funnel", "x": [0], "xaxis": "x", "y": [2353], "yaxis": "y"}, {"hovertemplate": "sentiment=%{x}<br>message=%{y}<extra></extra>", "legendgroup": "-1", "marker": {"color": "#ab63fa"}, "name": "-1", "orientation": "v", "showlegend": true, "type": "funnel", "x": [-1], "xaxis": "x", "y": [1296], "yaxis": "y"}],
#                         {"legend": {"title": {"text": "sentiment"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ti ...

# %% [markdown]
# ### Wordcloud Visualization

# %%
#pd.set_option('display.max_colwidth', 60)
# visualising the messages 
df_senti1 = train_df[train_df['sentiment']==1]
df_senti0 = train_df[train_df['sentiment']==0]
df_senti_neg1 = train_df[train_df['sentiment']==-1]
df_senti2 = train_df[train_df['sentiment']==2]
tweet_All = " ".join(review for review in train_df.message)
tweet_senti1 = " ".join(review for review in df_senti1.message)
tweet_senti0 = " ".join(review for review in df_senti0.message)
tweet_senti_neg1 = " ".join(review for review in df_senti_neg1.message)
tweet_senti2 = " ".join(review for review in df_senti2.message)

fig, ax = plt.subplots(5, 1, figsize  = (65,65))
# Create and generate a word cloud image:
wordcloud_ALL = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(tweet_All)
wordcloud_1 = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(tweet_senti1)
wordcloud_0 = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(tweet_senti0)
wordcloud_neg1 = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(tweet_senti_neg1)
wordcloud_2 = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(tweet_senti2)

# Display the generated image:
ax[0].imshow(wordcloud_ALL, interpolation='bilinear')
ax[0].set_title('All Tweets', fontsize=50)
ax[0].axis('off')
ax[1].imshow(wordcloud_1, interpolation='bilinear')
ax[1].set_title('Tweets under Pro Class 1',fontsize=50)
ax[1].axis('off')
ax[2].imshow(wordcloud_0, interpolation='bilinear')
ax[2].set_title('Tweets under Neutral Class 0',fontsize=50)
ax[2].axis('off')
ax[3].imshow(wordcloud_neg1, interpolation='bilinear')
ax[3].set_title('Tweets under Anti Class -1',fontsize=50)
ax[3].axis('off')
ax[4].imshow(wordcloud_2, interpolation='bilinear')
ax[4].set_title('Tweets under News Class 2',fontsize=50)
ax[4].axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
def jaccard(str1, str2): 
    '''It takes two strings can be two columns fro a df and returns intersection of twe two  divided by thier union'''
    a = set(str1.lower().split()) 
    b = set(str2.lower().split())
    c = a.intersection(b)
    return float(len(c)) / (len(a) + len(b) - len(c))

# %%
# on the train_df
results_jaccard=[]

for ind,row in train_df.iterrows():
    sentence1 = row.message
    sentence2 = row.clean_message

    jaccard_score = jaccard(sentence1,sentence2)
    results_jaccard.append([sentence1,sentence2,jaccard_score])

# %%
jaccard = pd.DataFrame(results_jaccard,columns=["message","clean_message","jaccard_score"])
train_df = train_df.merge(jaccard,how='outer')

# %%
train_df.head()
# Out:
#    sentiment  \
# 0          1
# 1          1
# 2          2
# 3          1
# 4          1
#
#                                                                                                message  \
# 0  PolySciMajor EPA chief doesn't think carbon dioxide is main cause of global warming and.. wait, ...
# 1                                       It's not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: It's 2016, and a racist, sexist, climate change denying bigot is leading in...
#
#    tweetid  \
# 0   625221
# 1   126103
# 2   698562
# 3   573736
# 4   466954
#
#                                                                                      fixed_cntractions  \
# 0  PolySciMajor EPA chief does not think carbon dioxide is main cause of global warming and.. wait,...
# 1                             it has / it is not like we lack evidence of anthropogenic global warming
# 2  RT @RawStory: Researchers say we have three years to act on climate change before it’s too late ...
# 3  #TodayinMaker# WIRED : 2016 was a pivotal year in the war on climate change https://t.co/44wOTxTLcD
# 4  RT @SoyNovioDeTodas: it has / it is 2016, and a racist, sexist, climate change denying bigot is ...
#
#                                                                                          clean_message  \
# 0  polyscimajor epa chief does not think carbon dioxide is main cause of global warming and wait wh...
# 1                               it has it is not like we lack evidence of anthropogenic global warming
# 2                 rt researchers say we have three years to act on climate change before it s too late
# 3                                               wired  was a pivotal year in the war on climate change
# 4            rt it has it is  and a racist sexist climate change denying bigot is leading in the polls
#
#                                                                                      tokenized_message  \
# 0  [polyscimajor, epa, chief, do, not, think, carbon, dioxide, be, main, cause, of, global, warming...
# 1        [, pron, have, pron, be, not, like, pron, lack, evidence, of, anthropogenic, global, warming]
# 2  [rt, researcher, say, pron, have, three, year, to, act, on, climate, change, before, pron, s, to...
# 3                                     [wired, be, a, pivotal, year, in, the, war, on, climate, change]
# 4  [rt, pron, have, pron, be, and, a, racist, sexist, climate, change, deny, bigot, be, lead, in, t...
#
#                                                                                            message_POS  \
# 0  [(polyscimajor, JJ), (epa, NN), (chief, NN), (does, VBZ), (not, RB), (think, VB), (carbon, NN), ...
# 1  [(it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (not, RB), (like, IN), (we, PRP), (lack, VBP), (ev...
# 2  [(rt, NN), (researchers, NNS), (say, VBP), (we, PRP), (have, VBP), (three, CD), (years, NNS), (t...
# 3  [(wired, VBN), (was, VBD), (a, DT), (pivotal, JJ), (year, NN), (in, IN), (the, DT), (war, NN), (...
# 4  [(rt, NN), (it, PRP), (has, VBZ), (it, PRP), (is, VBZ), (and, CC), (a, DT), (racist, NN), (sexis...
#
#                                                                                                 lemmaa  \
# 0  polyscimajor epa chief do not think carbon dioxide be main cause of global warming and wait what...
# 1                  -PRON- have -PRON- be not like -PRON- lack evidence of anthropogenic global warming
# 2           rt researcher say -PRON- have three year to act on climate change before -PRON- s too late
# 3                                               wired   be a pivotal year in the war on climate change
# 4         rt -PRON- have -PRON- be   and a racist sexist climate change deny bigot be lead in the poll
#
#                                                                                     clean_stp_words  \
# 0  [polyscimajor, epa, chief, not, think, carbon, dioxide, main, cause, global, warming, wait, via]
# 1                   [, pron, pron, not, like, pron, lack, evidence, anthropogenic, global, warming]
# 2                        [rt, researcher, say, pron, three, year, act, climate, change, pron, late]
# 3                                                      [wired, pivotal, year, war, climate, change]
# 4                        [rt, pron, pron, racist, sexist, climate, change, deny, bigot, lead, poll]
#
#    Num_words_raw  Num_words_clean  difference_in_wordsNo  jaccard_score
# 0             19               13                      6       0.541667
# 1             10               11                      1       0.692308
# 2             19               11                      8       0.714286
# 3             15                6                      9       0.733333
# 4             18               11                      7       0.478261

# %% [markdown]
# Diribution of number of words.

# %% [markdown]
# hist_data = [train_df['Num_words_raw'], train_df['Num_words_clean']]
#
# group_labels = ['message','clean_message']
#
# # Create distplot with custom bin_size
# fig = ff.create_distplot(hist_data, group_labels,show_curve=False)
# fig.update_layout(title_text='Distribution of Number Of words')
# fig.update_layout(
#     autosize=False,
#     width=900,
#     height=700,
#     paper_bgcolor="LightSteelBlue")
# fig.show()

# %% [markdown]
# The number of words plot is really interesting ,the tweets messages having number of words greater than 18 are very less and thus the number of words distribution plot is a little bit skewed the right

# %% [markdown]
# plt.figure(figsize=(12,6))
# p1=sns.kdeplot(train_df['Num_words_raw'], shade=True, color="r").set_title('Distribution of Number Of words')
# p2=sns.kdeplot(train_df['Num_words_clean'], shade=True, color="b")

# %% [markdown]
# #### Checking the differnce in number of words and jaccard_scores across different Sentiments

# %%
plt.figure(figsize=(12,6))
p1=sns.kdeplot(train_df[train_df['sentiment']== 1]['difference_in_wordsNo'], shade=True, color="b").set_title('Kernel Distribution of Difference in Number Of words')
p2=sns.kdeplot(train_df[train_df['sentiment']== -1]['difference_in_wordsNo'], shade=True, color="r")
p3=sns.kdeplot(train_df[train_df['sentiment']== 0]['difference_in_wordsNo'], shade=True, color="g")
p4=sns.kdeplot(train_df[train_df['sentiment']== 2]['difference_in_wordsNo'], shade=True, color="y")
plt.legend(labels=[1, -1, 0, 2])

# %% [markdown]
# sentiment 1 has the highest difference in number of words where the difference is by 5 words.

# %% [markdown]
# ### Most Common words in message

# %% [markdown]
# ### raw message

# %%
train_df['temp_list'] = train_df['message'].apply(lambda x:str(x).split())
top = Counter([item for sublist in train_df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row1_col1 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row2_col1 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row3_col1 {
#             background-color:  #2f7fbc;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row4_col1 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row5_col1 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row6_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row7_col1 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row8_col1 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row9_col1 {
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row10_col1 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row11_col1 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row12_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row13_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row14_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row15_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row16_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row17_col1 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row18_col1 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row19_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row0_col0" class="data row0 col0" >she's</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row0_col1" class="data row0 col1" >188525</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row1_col0" class="data row1 col0" >to</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row1_col1" class="data row1 col1" >145332</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row2_col0" class="data row2 col0" >RT</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row2_col1" class="data row2 col1" >144168</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row3_col0" class="data row3 col0" >climate</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row3_col1" class="data row3 col1" >141168</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row4_col0" class="data row4 col0" >in</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row4_col1" class="data row4 col1" >120700</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row5_col0" class="data row5 col0" >change</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row5_col1" class="data row5 col1" >115149</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row6_col0" class="data row6 col0" >believe</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row6_col1" class="data row6 col1" >114354</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row7_col0" class="data row7 col0" >going</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row7_col1" class="data row7 col1" >111717</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row8_col0" class="data row8 col0" >doesn't</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row8_col1" class="data row8 col1" >111533</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row9_col0" class="data row9 col0" >about</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row9_col1" class="data row9 col1" >97640</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row10_col0" class="data row10 col0" >your</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row10_col1" class="data row10 col1" >95072</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row11_col0" class="data row11 col0" >how</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row11_col1" class="data row11 col1" >95010</td>
#             </tr>
#             <tr>
#                         <th id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row12_col0" class="data row12 col0" >because</td>
#                         <td id="T_4c1d52a8_af54_11ea_96c9_fbdfd0c9d569row12_col1" c

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Raw message', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="338ab720-f0fb-4aad-bd19-71ba829c059b" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("338ab720-f0fb-4aad-bd19-71ba829c059b")) {
#                     Plotly.newPlot(
#                         '338ab720-f0fb-4aad-bd19-71ba829c059b',
#                         [{"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "she's", "marker": {"color": "#636efa"}, "name": "she's", "offsetgroup": "she's", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [188525], "xaxis": "x", "y": ["she's"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "to", "marker": {"color": "#EF553B"}, "name": "to", "offsetgroup": "to", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [145332], "xaxis": "x", "y": ["to"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "RT", "marker": {"color": "#00cc96"}, "name": "RT", "offsetgroup": "RT", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [144168], "xaxis": "x", "y": ["RT"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "climate", "marker": {"color": "#ab63fa"}, "name": "climate", "offsetgroup": "climate", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [141168], "xaxis": "x", "y": ["climate"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "in", "marker": {"color": "#FFA15A"}, "name": "in", "offsetgroup": "in", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [120700], "xaxis": "x", "y": ["in"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "change", "marker": {"color": "#19d3f3"}, "name": "change", "offsetgroup": "change", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [115149], "xaxis": "x", "y": ["change"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "believe", "marker": {"color": "#FF6692"}, "name": "believe", "offsetgroup": "believe", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [114354], "xaxis": "x", "y": ["believe"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "going", "marker": {"color": "#B6E880"}, "name": "going", "offsetgroup": "going", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [111717], "xaxis": "x", "y": ["going"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "doesn't", "marker": {"color": "#FF97FF"}, "name": "doesn't", "offsetgroup": "doesn't", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [111533], "xaxis": "x", "y": ["doesn't"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "about", "marker": {"color": "#FECB52"}, "name": "about", "offsetgroup": "about", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [97640], "xaxis": "x", "y": ["about"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "your", "marker": {"color": "#636efa"}, "name": "your", "offsetgroup": "your", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [95072], "xaxis": "x", "y": ["your"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "how", "marker": {"color": "#EF553B"}, "name": "how", "offsetgroup": "how", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [95010], "xaxis": "x", "y": ["how"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertempl ...
#                         {"barmode": "relative", "height": 700, "legend": {"title": {"text": "Common_words"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor

# %% [markdown]
# ### Clean messages

# %%
give reason to drop the

# %%
train_df['temp_list0'] = train_df['clean_stp_words'].apply(lambda x:str(x).split())
top = Counter([item for sublist in train_df['temp_list0'] for item in sublist])
temp0 = pd.DataFrame(top.most_common(20))
temp0.columns = ['Common_words','count']
temp0.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row1_col1 {
#             background-color:  #c1e6ba;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row2_col1 {
#             background-color:  #c3e7bc;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row3_col1 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row4_col1 {
#             background-color:  #d0edca;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row5_col1 {
#             background-color:  #d2edcc;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row6_col1 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row7_col1 {
#             background-color:  #d9f0d3;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row8_col1 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row9_col1 {
#             background-color:  #dbf1d5;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row10_col1 {
#             background-color:  #edf8e9;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row11_col1 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row12_col1 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row13_col1 {
#             background-color:  #f4fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row14_col1 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row15_col1 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row16_col1 {
#             background-color:  #f5fbf2;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row17_col1 {
#             background-color:  #f6fcf4;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row18_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row19_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row0_col0" class="data row0 col0" >'pron',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row0_col1" class="data row0 col1" >512857</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row1_col0" class="data row1 col0" >['rt',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row1_col1" class="data row1 col1" >144102</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row2_col0" class="data row2 col0" >'climate',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row2_col1" class="data row2 col1" >141535</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row3_col0" class="data row3 col0" >'not',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row3_col1" class="data row3 col1" >115679</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row4_col0" class="data row4 col0" >'believe',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row4_col1" class="data row4 col1" >114669</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row5_col0" class="data row5 col0" >'go',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row5_col1" class="data row5 col1" >112097</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row6_col0" class="data row6 col0" >'think',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row6_col1" class="data row6 col1" >98602</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row7_col0" class="data row7 col0" >'change']</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row7_col1" class="data row7 col1" >97141</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row8_col0" class="data row8 col0" >'die',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row8_col1" class="data row8 col1" >94484</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row9_col0" class="data row9 col0" >'husband',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row9_col1" class="data row9 col1" >94256</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row10_col0" class="data row10 col0" >'change',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row10_col1" class="data row10 col1" >44790</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row11_col0" class="data row11 col0" >'president',</td>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row11_col1" class="data row11 col1" >18653</td>
#             </tr>
#             <tr>
#                         <th id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_97c1b436_af54_11ea_9c10_fbdfd0c9d569row12_col0" class="data row12 col0" >'elect',</td>
#                         <td id="T_97c1b436

# %%
fig = px.bar(temp0, x="count", y="Common_words", title='Commmon Words in cleaned message', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()
# Out:
# <div>
#
#
#             <div id="8dc62ac2-34aa-4881-a82c-4dafabc11ac5" class="plotly-graph-div" style="height:700px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8dc62ac2-34aa-4881-a82c-4dafabc11ac5")) {
#                     Plotly.newPlot(
#                         '8dc62ac2-34aa-4881-a82c-4dafabc11ac5',
#                         [{"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'pron',", "marker": {"color": "#636efa"}, "name": "'pron',", "offsetgroup": "'pron',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [512857], "xaxis": "x", "y": ["'pron',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "['rt',", "marker": {"color": "#EF553B"}, "name": "['rt',", "offsetgroup": "['rt',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [144102], "xaxis": "x", "y": ["['rt',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'climate',", "marker": {"color": "#00cc96"}, "name": "'climate',", "offsetgroup": "'climate',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [141535], "xaxis": "x", "y": ["'climate',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'not',", "marker": {"color": "#ab63fa"}, "name": "'not',", "offsetgroup": "'not',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [115679], "xaxis": "x", "y": ["'not',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'believe',", "marker": {"color": "#FFA15A"}, "name": "'believe',", "offsetgroup": "'believe',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [114669], "xaxis": "x", "y": ["'believe',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'go',", "marker": {"color": "#19d3f3"}, "name": "'go',", "offsetgroup": "'go',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [112097], "xaxis": "x", "y": ["'go',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'think',", "marker": {"color": "#FF6692"}, "name": "'think',", "offsetgroup": "'think',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [98602], "xaxis": "x", "y": ["'think',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'change']", "marker": {"color": "#B6E880"}, "name": "'change']", "offsetgroup": "'change']", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [97141], "xaxis": "x", "y": ["'change']"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'die',", "marker": {"color": "#FF97FF"}, "name": "'die',", "offsetgroup": "'die',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [94484], "xaxis": "x", "y": ["'die',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'husband',", "marker": {"color": "#FECB52"}, "name": "'husband',", "offsetgroup": "'husband',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [94256], "xaxis": "x", "y": ["'husband',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'change',", "marker": {"color": "#636efa"}, "name": "'change',", "offsetgroup": "'change',", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [44790], "xaxis": "x", "y": ["'change',"], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Common_words=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "'president',", "marker": {"color": "#EF553B"}, "name": "'president',", "offsetgroup": "'president',", "orientation": ...
#                         {"barmode": "relative", "height": 700, "legend": {"title": {"text": "Common_words"}, "tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white"

# %% [markdown]
# with stop words removed, now the most common word is climate

# %% [markdown]
# ## Most common words sentiment wise in raw message

# %%
Pro = train_df[train_df['sentiment']==1]
Anti = train_df[train_df['sentiment']== -1]
Neutral = train_df[train_df['sentiment']==0]
News = train_df[train_df['sentiment']== 2]

# %%
#MosT common positive words(Pro)
top = Counter([item for sublist in Pro['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row0_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row1_col1 {
#             background-color:  #2e964d;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row2_col1 {
#             background-color:  #339c52;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row3_col1 {
#             background-color:  #37a055;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row4_col1 {
#             background-color:  #5ab769;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row5_col1 {
#             background-color:  #66bd6f;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row6_col1 {
#             background-color:  #6dc072;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row7_col1 {
#             background-color:  #6dc072;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row8_col1 {
#             background-color:  #70c274;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row9_col1 {
#             background-color:  #91d28e;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row10_col1 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row11_col1 {
#             background-color:  #94d390;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row12_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row13_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row14_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row15_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row16_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row17_col1 {
#             background-color:  #95d391;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row18_col1 {
#             background-color:  #f1faee;
#             color:  #000000;
#         }    #T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row19_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }</style><table id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row0_col0" class="data row0 col0" >she's</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row0_col1" class="data row0 col1" >188520</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row1_col0" class="data row1 col0" >to</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row1_col1" class="data row1 col1" >141232</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row2_col0" class="data row2 col0" >RT</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row2_col1" class="data row2 col1" >137813</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row3_col0" class="data row3 col0" >climate</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row3_col1" class="data row3 col1" >135305</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row4_col0" class="data row4 col0" >in</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row4_col1" class="data row4 col1" >118967</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row5_col0" class="data row5 col0" >believe</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row5_col1" class="data row5 col1" >114203</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row6_col0" class="data row6 col0" >going</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row6_col1" class="data row6 col1" >111586</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row7_col0" class="data row7 col0" >doesn't</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row7_col1" class="data row7 col1" >111447</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row8_col0" class="data row8 col0" >change</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row8_col1" class="data row8 col1" >110598</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row9_col0" class="data row9 col0" >about</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row9_col1" class="data row9 col1" >95966</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row10_col0" class="data row10 col0" >your</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row10_col1" class="data row10 col1" >94929</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row11_col0" class="data row11 col0" >how</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row11_col1" class="data row11 col1" >94852</td>
#             </tr>
#             <tr>
#                         <th id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row12_col0" class="data row12 col0" >die</td>
#                         <td id="T_09eeaa62_af55_11ea_9814_fbdfd0c9d569row12_col1" class

# %%
#MosT common negative words(Anti)
top = Counter([item for sublist in Anti['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row1_col1 {
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row2_col1 {
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row3_col1 {
#             background-color:  #f14130;
#             color:  #f1f1f1;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row4_col1 {
#             background-color:  #fb7757;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row5_col1 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row6_col1 {
#             background-color:  #fcb499;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row7_col1 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row8_col1 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row9_col1 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row10_col1 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row11_col1 {
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row12_col1 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row13_col1 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row14_col1 {
#             background-color:  #ffece3;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row15_col1 {
#             background-color:  #fff3ed;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row16_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row17_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row0_col0" class="data row0 col0" >the</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row0_col1" class="data row0 col1" >1464</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row1_col0" class="data row1 col0" >to</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row1_col1" class="data row1 col1" >1167</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row2_col0" class="data row2 col0" >of</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row2_col1" class="data row2 col1" >1097</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row3_col0" class="data row3 col0" >global</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row3_col1" class="data row3 col1" >1081</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row4_col0" class="data row4 col0" >warming</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row4_col1" class="data row4 col1" >938</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row5_col0" class="data row5 col0" >climate</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row5_col1" class="data row5 col1" >805</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row6_col0" class="data row6 col0" >The</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row6_col1" class="data row6 col1" >753</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row7_col0" class="data row7 col0" >by</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row7_col1" class="data row7 col1" >733</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row8_col0" class="data row8 col0" >is</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row8_col1" class="data row8 col1" >718</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row9_col0" class="data row9 col0" >in</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row9_col1" class="data row9 col1" >712</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row10_col0" class="data row10 col0" >@realDonaldTrump:</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row10_col1" class="data row10 col1" >705</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row11_col0" class="data row11 col0" >and</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row11_col1" class="data row11 col1" >689</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row12_col0" class="data row12 col0" >for</td>
#                         <td id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569row12_col1" class="data row12 col1" >648</td>
#             </tr>
#             <tr>
#                         <th id="T_17b78d76_af55_11ea_b8e9_fbdfd0c9d569level0_row13" class="row_he

# %%
#MosT common words in Neutral sentiment
top = Counter([item for sublist in Neutral['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row1_col1 {
#             background-color:  #900a12;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row2_col1 {
#             background-color:  #ab1016;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row3_col1 {
#             background-color:  #af1117;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row4_col1 {
#             background-color:  #e32f27;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row5_col1 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row6_col1 {
#             background-color:  #f5533b;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row7_col1 {
#             background-color:  #fc8464;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row8_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row9_col1 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row10_col1 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row11_col1 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row12_col1 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row13_col1 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row14_col1 {
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row15_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row16_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row17_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row0_col0" class="data row0 col0" >rt</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row0_col1" class="data row0 col1" >2179</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row1_col0" class="data row1 col0" >is</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row1_col1" class="data row1 col1" >2047</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row2_col0" class="data row2 col0" >global</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row2_col1" class="data row2 col1" >1944</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row3_col0" class="data row3 col0" >warming</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row3_col1" class="data row3 col1" >1923</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row4_col0" class="data row4 col0" >climate</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row4_col1" class="data row4 col1" >1644</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row5_col0" class="data row5 col0" >change</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row5_col1" class="data row5 col1" >1629</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row6_col0" class="data row6 col0" >has</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row6_col1" class="data row6 col1" >1474</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row7_col0" class="data row7 col0" >to</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row7_col1" class="data row7 col1" >1248</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row8_col0" class="data row8 col0" >about</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row8_col1" class="data row8 col1" >1114</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row9_col0" class="data row9 col0" >the</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row9_col1" class="data row9 col1" >1038</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row10_col0" class="data row10 col0" >a</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row10_col1" class="data row10 col1" >994</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row11_col0" class="data row11 col0" >do</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row11_col1" class="data row11 col1" >983</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row12_col0" class="data row12 col0" >you</td>
#                         <td id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569row12_col1" class="data row12 col1" >978</td>
#             </tr>
#             <tr>
#                         <th id="T_1e66ab7e_af27_11ea_9d4d_fbdfd0c9d569level0_row13" class="row_headin

# %%
#MosT common words in News sentiment
top = Counter([item for sublist in News['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row1_col1 {
#             background-color:  #a81016;
#             color:  #f1f1f1;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row2_col1 {
#             background-color:  #f75c41;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row3_col1 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row4_col1 {
#             background-color:  #fcbda4;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row5_col1 {
#             background-color:  #fcc4ad;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row6_col1 {
#             background-color:  #fdc6b0;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row7_col1 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row8_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row9_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row10_col1 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row11_col1 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row12_col1 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row13_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row14_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row15_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row16_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row17_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common_words</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row0_col0" class="data row0 col0" >change</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row0_col1" class="data row0 col1" >2939</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row1_col0" class="data row1 col0" >RT</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row1_col1" class="data row1 col1" >2575</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row2_col0" class="data row2 col0" >to</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row2_col1" class="data row2 col1" >1706</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row3_col0" class="data row3 col0" >Trump</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row3_col1" class="data row3 col1" >1032</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row4_col0" class="data row4 col0" >the</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row4_col1" class="data row4 col1" >918</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row5_col0" class="data row5 col0" >on</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row5_col1" class="data row5 col1" >859</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row6_col0" class="data row6 col0" >of</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row6_col1" class="data row6 col1" >837</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row7_col0" class="data row7 col0" >a</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row7_col1" class="data row7 col1" >635</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row8_col0" class="data row8 col0" >global</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row8_col1" class="data row8 col1" >527</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row9_col0" class="data row9 col0" >in</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row9_col1" class="data row9 col1" >525</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row10" class="row_heading level0 row10" >11</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row10_col0" class="data row10 col0" >and</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row10_col1" class="data row10 col1" >501</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row11" class="row_heading level0 row11" >12</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row11_col0" class="data row11 col0" >is</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row11_col1" class="data row11 col1" >406</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row12" class="row_heading level0 row12" >13</th>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row12_col0" class="data row12 col0" >warming</td>
#                         <td id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569row12_col1" class="data row12 col1" >373</td>
#             </tr>
#             <tr>
#                         <th id="T_1f58c4cc_af55_11ea_a28a_fbdfd0c9d569level0_row13" class="row_heading level0 row

# %% [markdown]
# ### Below is modeling of the raw data

# %%
from sklearn.model_selection import train_test_split

# %%
X = train_df['message']
y = train_df['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state = 42 )

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer()

# %%
#fiit the vactorize to data build vocab 
#count_vect.fit(X_train)
#X_train_count = count_vect.transform(X_train)
#transform
X_train_count = count_vect.fit_transform(X_train)

# %%
X_train_count

# %%
X_train.shape

# %%
X_train_count.shape

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer()

# %%
X_train_tfidf = tfidf_transformer.fit_transform(X_train_count)

# %%
X_train_tfidf.shape

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
X_train_tfidf = vectorizer.fit_transform(X_train)

# %%
from sklearn.svm import LinearSVC

# %%
clf = LinearSVC()

# %%
clf.fit(X_train_tfidf, y_train)

# %%
from sklearn.pipeline import Pipeline

# %%
text_clf = Pipeline([('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
text_clf.fit(X_train, y_train)

# %%
predictions = text_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predictions))

# %%
print(classification_report(y_test,predictions))

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test, predictions)

# %%
metrics.f1_score(y_test, predictions, average='micro')

# %%
X_train1 = train_df['message']
y_train1 = train_df['sentiment']
X_test1 = test_df['message']

# %%
text_clf.fit(X_train1, y_train1)

# %%
text_clf_pred = text_clf.predict(X_test1)

# %%
text_clf_pred = pd.DataFrame(data=text_clf_pred,
                                 columns=['sentiment'],
                                 index=test_df['tweetid'])
text_clf_pred.reset_index(inplace=True)

# %%
text_clf_pred

# %%
text_clf_pred.to_csv("../output", index=False)

# %%
text_clf_pred

# %% [markdown]
# checking

# %%
train_df.head()

# %%
#checking for blanks
train_df[train_df['message'] == ' '].index

# %% [markdown]
# the are no blanks in the massage entries

# %% [markdown]
# checking for duplicated entries

# %%
duplicateRowsDF = train_df[train_df.duplicated(['message'])]

# %%
duplicateRowsDF

# %% [markdown]
# the duplicated massages are the retweets.

# %%
train_df.shape

# %%
data = train_df.drop_duplicates(subset ="message", 
                     keep = False, inplace = True)

# %%
dat = train_df.drop_duplicates(subset='message', keep='first')

# %%
dat.shape

# %%
dat

# %%
dat_duplicated = dat[dat.duplicated(['message'])]

# %%
dat_duplicated
